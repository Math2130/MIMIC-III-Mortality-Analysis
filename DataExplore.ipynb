# %%
import pandas as pd

# %%
OUTPUTEVENTS = pd.read_csv("mimic-iii-clinical-database-1.4/OUTPUTEVENTS.csv.gz")

# %%
OUTPUTEVENTS
# Out:
#           ROW_ID  SUBJECT_ID   HADM_ID  ICUSTAY_ID            CHARTTIME  \
# 0            344       21219  177991.0    225765.0  2142-09-08 10:00:00
# 1            345       21219  177991.0    225765.0  2142-09-08 12:00:00
# 2            346       21219  177991.0    225765.0  2142-09-08 13:00:00
# 3            347       21219  177991.0    225765.0  2142-09-08 14:00:00
# 4            348       21219  177991.0    225765.0  2142-09-08 16:00:00
# ...          ...         ...       ...         ...                  ...
# 4349213  4340476       68375  123645.0    276251.0  2175-09-05 23:00:00
# 4349214  4340477       68375  123645.0    276251.0  2175-09-06 00:00:00
# 4349215  4340478       68375  123645.0    276251.0  2175-09-06 01:00:00
# 4349216  4340479       68375  123645.0    276251.0  2175-09-06 02:00:00
# 4349217  4340480       68375  123645.0    276251.0  2175-09-06 04:00:00
#
#          ITEMID  VALUE VALUEUOM            STORETIME   CGID  STOPPED  \
# ...

# %%
patient_admissions = pd.read_csv("mimic-iii-clinical-database-1.4/ADMISSIONS.csv.gz")

# %%
patient_admissions
# Out:
#        ROW_ID  SUBJECT_ID  HADM_ID            ADMITTIME            DISCHTIME  \
# 0          21          22   165315  2196-04-09 12:26:00  2196-04-10 15:54:00
# 1          22          23   152223  2153-09-03 07:15:00  2153-09-08 19:10:00
# 2          23          23   124321  2157-10-18 19:34:00  2157-10-25 14:00:00
# 3          24          24   161859  2139-06-06 16:14:00  2139-06-09 12:48:00
# 4          25          25   129635  2160-11-02 02:06:00  2160-11-05 14:55:00
# ...       ...         ...      ...                  ...                  ...
# 58971   58594       98800   191113  2131-03-30 21:13:00  2131-04-02 15:02:00
# 58972   58595       98802   101071  2151-03-05 20:00:00  2151-03-06 09:10:00
# 58973   58596       98805   122631  2200-09-12 07:15:00  2200-09-20 12:08:00
# 58974   58597       98813   170407  2128-11-11 02:29:00  2128-12-22 13:11:00
# 58975   58598       98813   190264  2131-10-25 03:09:00  2131-10-26 17:44:00
#
# ...

# %%
patient_callout = pd.read_csv("mimic-iii-clinical-database-1.4/CALLOUT.csv.gz")
patient_callout
# Out:
#        ROW_ID  SUBJECT_ID  HADM_ID  SUBMIT_WARDID SUBMIT_CAREUNIT  \
# 0         402         854   175684           52.0             NaN
# 1         403         864   138624           15.0             NaN
# 2         404         864   138624           12.0             NaN
# 3         405         867   184298            7.0             NaN
# 4         157         306   167129           57.0             NaN
# ...       ...         ...      ...            ...             ...
# 34494   32674       94046   199742           23.0             NaN
# 34495   32675       94049   135809           23.0             NaN
# 34496   32676       94050   173013           23.0             NaN
# 34497   32677       94056   172374           50.0             NaN
# 34498   32678       94057   113695           23.0            MICU
#
#        CURR_WARDID CURR_CAREUNIT  CALLOUT_WARDID CALLOUT_SERVICE  \
# 0             29.0          MICU               1             MED
# ...

# %%
caregivers = pd.read_csv("mimic-iii-clinical-database-1.4/CAREGIVERS.csv.gz")
caregivers
# Out:
#       ROW_ID   CGID LABEL            DESCRIPTION
# 0       2228  16174    RO              Read Only
# 1       2229  16175    RO              Read Only
# 2       2230  16176   Res  Resident/Fellow/PA/NP
# 3       2231  16177    RO              Read Only
# 4       2232  16178    RT            Respiratory
# ...      ...    ...   ...                    ...
# 7562    6300  20303    MD                    NaN
# 7563    6301  20304    RN                     RN
# 7564    6302  20305   MDs                    NaN
# 7565    6303  20306   RPH             Pharmacist
# 7566    6304  20307    RO              Read Only
#
# [7567 rows x 4 columns]

# %%
chartevents = pd.read_csv("mimic-iii-clinical-database-1.4/CHARTEVENTS.csv.gz", compression='gzip')
chartevents
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 chartevents = pd.read_csv("mimic-iii-clinical-database-1.4/CHARTEVENTS.csv.gz", compression='gzip')
#       2 chartevents
#
# ...

# %%
cptevents = pd.read_csv("mimic-iii-clinical-database-1.4/CPTEVENTS.csv.gz")
cptevents
# Out:
# /var/folders/kw/fxbbvv5x7lvct1l7rdc18tkw0000gn/T/ipykernel_62638/1910783996.py:1: DtypeWarning: Columns (4,5,7,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   cptevents = pd.read_csv("mimic-iii-clinical-database-1.4/CPTEVENTS.csv.gz")
#         ROW_ID  SUBJECT_ID  HADM_ID COSTCENTER            CHARTDATE CPT_CD  \
# 0          317       11743   129545        ICU                  NaN  99232
# 1          318       11743   129545        ICU                  NaN  99232
# 2          319       11743   129545        ICU                  NaN  99232
# 3          320       11743   129545        ICU                  NaN  99232
# 4          321        6185   183725        ICU                  NaN  99223
# ...        ...         ...      ...        ...                  ...    ...
# 573141  573142       78876   163404       Resp  2105-09-01 00:00:00  94003
# 573142  573143       78879   136071       Resp  2150-08-29 00:00:00  94003
# ...

# %%
ICUSTAYS = pd.read_csv("mimic-iii-clinical-database-1.4/ICUSTAYS.csv.gz")
ICUSTAYS
# Out:
#        ROW_ID  SUBJECT_ID  HADM_ID  ICUSTAY_ID    DBSOURCE FIRST_CAREUNIT  \
# 0         365         268   110404      280836     carevue           MICU
# 1         366         269   106296      206613     carevue           MICU
# 2         367         270   188028      220345     carevue            CCU
# 3         368         271   173727      249196     carevue           MICU
# 4         369         272   164716      210407     carevue            CCU
# ...       ...         ...      ...         ...         ...            ...
# 61527   59806       94944   143774      201233  metavision           CSRU
# 61528   59807       94950   123750      283653  metavision            CCU
# 61529   59808       94953   196881      241585  metavision           SICU
# 61530   59809       94954   118475      202802  metavision           CSRU
# 61531   59810       94956   156386      275346  metavision          TSICU
#
#       LAST_CAREUNIT  FIRST_WARDID  LAST_WARDID               INTIME  \
# ...

# %%
TRANSFERS = pd.read_csv("mimic-iii-clinical-database-1.4/TRANSFERS.csv.gz")
TRANSFERS
# Out:
#         ROW_ID  SUBJECT_ID  HADM_ID  ICUSTAY_ID    DBSOURCE  EVENTTYPE  \
# 0          657         111   192123    254245.0     carevue   transfer
# 1          658         111   192123         NaN     carevue   transfer
# 2          659         111   192123         NaN     carevue  discharge
# 3          660         111   155897    249202.0  metavision      admit
# 4          661         111   155897         NaN  metavision   transfer
# ...        ...         ...      ...         ...         ...        ...
# 261892  259671       98385   195599         NaN  metavision   transfer
# 261893  259672       98385   195599    292167.0  metavision   transfer
# 261894  259673       98385   195599         NaN  metavision  discharge
# 261895  259674       98389   155368         NaN  metavision      admit
# 261896  259675       98389   155368         NaN  metavision   transfer
#
#        PREV_CAREUNIT CURR_CAREUNIT  PREV_WARDID  CURR_WARDID  \
# ...

# %%
patients = pd.read_csv("mimic-iii-clinical-database-1.4/PATIENTS.csv.gz")
patients
# Out:
#        ROW_ID  SUBJECT_ID GENDER                  DOB                  DOD  \
# 0         234         249      F  2075-03-13 00:00:00                  NaN
# 1         235         250      F  2164-12-27 00:00:00  2188-11-22 00:00:00
# 2         236         251      M  2090-03-15 00:00:00                  NaN
# 3         237         252      M  2078-03-06 00:00:00                  NaN
# 4         238         253      F  2089-11-26 00:00:00                  NaN
# ...       ...         ...    ...                  ...                  ...
# 46515   31840       44089      M  2026-05-25 00:00:00                  NaN
# 46516   31841       44115      F  2124-07-27 00:00:00                  NaN
# 46517   31842       44123      F  2049-11-26 00:00:00  2135-01-12 00:00:00
# 46518   31843       44126      F  2076-07-25 00:00:00                  NaN
# 46519   31844       44128      M  2098-07-25 00:00:00                  NaN
#
#                   DOD_HOSP DOD_SSN  EXPIRE_FLAG
# ...

# %%
dcpt = pd.read_csv("mimic-iii-clinical-database-1.4/D_CPT.csv.gz")
dcpt
# Out:
#      ROW_ID  CATEGORY SECTIONRANGE              SECTIONHEADER SUBSECTIONRANGE  \
# 0         1         1  99201-99499  Evaluation and management     99201-99216
# 1         2         1  99201-99499  Evaluation and management     99217-99220
# 2         3         1  99201-99499  Evaluation and management     99221-99239
# 3         4         1  99201-99499  Evaluation and management     99241-99255
# 4         5         1  99201-99499  Evaluation and management     99261-99263
# ..      ...       ...          ...                        ...             ...
# 129     130         2  0001F-7025F    Performance measurement     5005F-5100F
# 130     131         2  0001F-7025F    Performance measurement     6005F-6045F
# 131     132         2  0001F-7025F    Performance measurement     7010F-7025F
# 132     133         3  0016T-0207T        Emerging technology     0016T-0207T
# 133     134         3  0256T-0259T        Emerging technology     0256T-0259T
#
# ...

# %%
dcpt_diagnoses = pd.read_csv("mimic-iii-clinical-database-1.4/D_ICD_DIAGNOSES.csv.gz")
dcpt_diagnoses
# Out:
#        ROW_ID ICD9_CODE               SHORT_TITLE  \
# 0         174     01166     TB pneumonia-oth test
# 1         175     01170    TB pneumothorax-unspec
# 2         176     01171   TB pneumothorax-no exam
# 3         177     01172  TB pneumothorx-exam unkn
# 4         178     01173  TB pneumothorax-micro dx
# ...       ...       ...                       ...
# 14562   14432     V7399     Scrn unspcf viral dis
# 14563   14433      V740     Screening for cholera
# 14564   14434      V741    Screening-pulmonary TB
# 14565   14435      V742     Screening for leprosy
# 14566   14436      V743  Screening for diphtheria
#
#                                               LONG_TITLE
# 0      Tuberculous pneumonia [any form], tubercle bac...
# 1                  Tuberculous pneumothorax, unspecified
# 2      Tuberculous pneumothorax, bacteriological or h...
# 3      Tuberculous pneumothorax, bacteriological or h...
# 4      Tuberculous pneumothorax, tubercle bacilli fou...
# ...

# %%
dcpt_procedures = pd.read_csv("mimic-iii-clinical-database-1.4/D_ICD_PROCEDURES.csv.gz")
dcpt_procedures
# Out:
#       ROW_ID  ICD9_CODE               SHORT_TITLE  \
# 0        264        851                Canthotomy
# 1        265        852           Blepharorrhaphy
# 2        266        859   Adjust lid position NEC
# 3        267        861  Lid reconst w skin graft
# 4        268        862   Lid reconst w muc graft
# ...      ...        ...                       ...
# 3877    3344       9959  Vaccination/innocula NEC
# 3878    3345       9960  Cardiopulm resuscita NOS
# 3879    3346       9961      Atrial cardioversion
# 3880    3347       9962    Heart countershock NEC
# 3881    3348       9963  Closed chest card massag
#
#                                              LONG_TITLE
# 0                                            Canthotomy
# 1                                       Blepharorrhaphy
# 2                      Other adjustment of lid position
# 3      Reconstruction of eyelid with skin flap or graft
# 4     Reconstruction of eyelid with mucous membrane ...
# ...

# %%
dcpt_items = pd.read_csv("mimic-iii-clinical-database-1.4/D_ITEMS.csv.gz")
dcpt_items
# Out:
#        ROW_ID  ITEMID                                        LABEL  \
# 0         457     497  Patient controlled analgesia (PCA) [Inject]
# 1         458     498                            PCA Lockout (Min)
# 2         459     499                               PCA Medication
# 3         460     500                               PCA Total Dose
# 4         461     501                           PCV Exh Vt (Obser)
# ...       ...     ...                                          ...
# 12482   14518  226757                        GCSMotorApacheIIValue
# 12483   14519  226758                       GCSVerbalApacheIIValue
# 12484   14520  226759                            HCO3ApacheIIValue
# 12485   14521  226760                                    HCO3Score
# 12486   14522  226761                      HematocritApacheIIScore
#
#                   ABBREVIATION    DBSOURCE      LINKSTO            CATEGORY  \
# 0                          NaN     carevue  chartevents                 NaN
# ...

# %%
dcpt_labitems = pd.read_csv("mimic-iii-clinical-database-1.4/D_LABITEMS.csv.gz")
dcpt_labitems
# Out:
#      ROW_ID  ITEMID                       LABEL                      FLUID  \
# 0       546   51346                      Blasts  Cerebrospinal Fluid (CSF)
# 1       547   51347                 Eosinophils  Cerebrospinal Fluid (CSF)
# 2       548   51348             Hematocrit, CSF  Cerebrospinal Fluid (CSF)
# 3       549   51349  Hypersegmented Neutrophils  Cerebrospinal Fluid (CSF)
# 4       550   51350           Immunophenotyping  Cerebrospinal Fluid (CSF)
# ..      ...     ...                         ...                        ...
# 748     749   51551             VOIDED SPECIMEN           OTHER BODY FLUID
# 749     750   51552             VOIDED SPECIMEN                      STOOL
# 750     751   51553             VOIDED SPECIMEN                      URINE
# 751     752   51554             VOIDED SPECIMEN                JOINT FLUID
# 752     753   51555    SURFACTANT ALBUMIN RATIO           OTHER BODY FLUID
#
#        CATEGORY LOINC_CODE
# 0    Hematology    26447-3
# ...

# %%
diagnoses = pd.read_csv("mimic-iii-clinical-database-1.4/DIAGNOSES_ICD.csv.gz")
diagnoses
# Out:
#         ROW_ID  SUBJECT_ID  HADM_ID  SEQ_NUM ICD9_CODE
# 0         1297         109   172335      1.0     40301
# 1         1298         109   172335      2.0       486
# 2         1299         109   172335      3.0     58281
# 3         1300         109   172335      4.0      5855
# 4         1301         109   172335      5.0      4254
# ...        ...         ...      ...      ...       ...
# 651042  639798       97503   188195      2.0     20280
# 651043  639799       97503   188195      3.0     V5869
# 651044  639800       97503   188195      4.0     V1279
# 651045  639801       97503   188195      5.0      5275
# 651046  639802       97503   188195      6.0      5569
#
# [651047 rows x 5 columns]

# %%
date_time = pd.read_csv("mimic-iii-clinical-database-1.4/DATETIMEEVENTS.csv.gz")
date_time
# Out:
# /var/folders/kw/fxbbvv5x7lvct1l7rdc18tkw0000gn/T/ipykernel_62638/2304523939.py:1: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   date_time = pd.read_csv("mimic-iii-clinical-database-1.4/DATETIMEEVENTS.csv.gz")
#           ROW_ID  SUBJECT_ID   HADM_ID  ICUSTAY_ID  ITEMID  \
# 0            711        7657  121183.0    297945.0    3411
# 1            712        7657  121183.0    297945.0    3411
# 2            713        7657  121183.0    297945.0    3411
# 3            714        7657  121183.0    297945.0    3411
# 4            715        7657  121183.0    297945.0    3411
# ...          ...         ...       ...         ...     ...
# 4485932  4456093       99366  136021.0    218447.0  224279
# 4485933  4456094       99366  136021.0    218447.0  224280
# 4485934  4456095       99366  136021.0    218447.0  224282
# 4485935  4456096       99366  136021.0    218447.0  224284
# ...

# %%
drugs = pd.read_csv("mimic-iii-clinical-database-1.4/DRGCODES.csv.gz")
drugs
# Out:
#         ROW_ID  SUBJECT_ID  HADM_ID DRG_TYPE  DRG_CODE  \
# 0          342        2491   144486     HCFA        28
# 1          343       24958   162910     HCFA       110
# 2          344       18325   153751     HCFA       390
# 3          345       17887   182692     HCFA        14
# 4          346       11113   157980     HCFA       390
# ...        ...         ...      ...      ...       ...
# 125552  123452       71582   101422       MS       221
# 125553  123453       46449   110075     APR       1653
# 125554  123454       46449   110075     APR       1653
# 125555  123455       46449   110075       MS       234
# 125556  123456       87879   155607     APR       6813
#
#                                               DESCRIPTION  DRG_SEVERITY  \
# 0       TRAUMATIC STUPOR & COMA, COMA <1 HR AGE >17 WI...           NaN
# 1       MAJOR CARDIOVASCULAR PROCEDURES WITH COMPLICAT...           NaN
# 2                 NEONATE WITH OTHER SIGNIFICANT PROBLEMS           NaN
# ...

# %%
procedures = pd.read_csv("mimic-iii-clinical-database-1.4/PROCEDURES_ICD.csv.gz")
procedures
# Out:
#         ROW_ID  SUBJECT_ID  HADM_ID  SEQ_NUM  ICD9_CODE
# 0          944       62641   154460        3       3404
# 1          945        2592   130856        1       9671
# 2          946        2592   130856        2       3893
# 3          947       55357   119355        1       9672
# 4          948       55357   119355        2        331
# ...        ...         ...      ...      ...        ...
# 240090  228330       67415   150871        5       3736
# 240091  228331       67415   150871        6       3893
# 240092  228332       67415   150871        7       8872
# 240093  228333       67415   150871        8       3893
# 240094  228334       67415   150871        9       3722
#
# [240095 rows x 5 columns]

# %%
procedure_events = pd.read_csv("mimic-iii-clinical-database-1.4/PROCEDUREEVENTS_MV.csv.gz")
procedure_events
# Out:
#         ROW_ID  SUBJECT_ID  HADM_ID  ICUSTAY_ID            STARTTIME  \
# 0          379       29070   115071    232563.0  2145-03-12 23:04:00
# 1          380       29070   115071    232563.0  2145-03-12 23:04:00
# 2          381       29070   115071    232563.0  2145-03-12 23:05:00
# 3          382       29070   115071    232563.0  2145-03-12 23:36:00
# 4          383       29070   115071    232563.0  2145-03-13 01:27:00
# ...        ...         ...      ...         ...                  ...
# 258061  257337       41958   182711    246007.0  2155-08-09 01:51:00
# 258062  257338       41958   182711    246007.0  2155-08-09 01:57:00
# 258063  257339       41958   182711    246007.0  2155-08-09 01:57:00
# 258064  257340       41958   182711    246007.0  2155-08-09 01:57:00
# 258065  257341       41958   182711    246007.0  2155-08-09 02:20:00
#
#                     ENDTIME  ITEMID   VALUE VALUEUOM         LOCATION  ...  \
# ...

# %%
prescriptions = pd.read_csv("mimic-iii-clinical-database-1.4/PRESCRIPTIONS.csv.gz")
prescriptions
# Out:
# /var/folders/kw/fxbbvv5x7lvct1l7rdc18tkw0000gn/T/ipykernel_62638/3117434484.py:1: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   prescriptions = pd.read_csv("mimic-iii-clinical-database-1.4/PRESCRIPTIONS.csv.gz")
#           ROW_ID  SUBJECT_ID  HADM_ID  ICUSTAY_ID            STARTDATE  \
# 0        2214776           6   107064         NaN  2175-06-11 00:00:00
# 1        2214775           6   107064         NaN  2175-06-11 00:00:00
# 2        2215524           6   107064         NaN  2175-06-11 00:00:00
# 3        2216265           6   107064         NaN  2175-06-11 00:00:00
# 4        2214773           6   107064         NaN  2175-06-11 00:00:00
# ...          ...         ...      ...         ...                  ...
# 4156445  3996662       98887   121032    238144.0  2144-09-06 00:00:00
# 4156446  3996070       98887   121032    238144.0  2144-09-06 00:00:00
# ...

# %%
LABEVENTS = pd.read_csv("mimic-iii-clinical-database-1.4/LABEVENTS.csv.gz")
LABEVENTS
# Out:
#             ROW_ID  SUBJECT_ID   HADM_ID  ITEMID            CHARTTIME VALUE  \
# 0              281           3       NaN   50820  2101-10-12 16:07:00  7.39
# 1              282           3       NaN   50800  2101-10-12 18:17:00   ART
# 2              283           3       NaN   50802  2101-10-12 18:17:00    -1
# 3              284           3       NaN   50804  2101-10-12 18:17:00    22
# 4              285           3       NaN   50808  2101-10-12 18:17:00  0.93
# ...            ...         ...       ...     ...                  ...   ...
# 27854050  27428435       96443  103219.0   50882  2109-12-30 01:40:00    26
# 27854051  27428436       96443  103219.0   50885  2109-12-30 01:40:00   2.1
# 27854052  27428437       96443  103219.0   50902  2109-12-30 01:40:00    97
# 27854053  27428438       96443  103219.0   50911  2109-12-30 01:40:00     2
# 27854054  27428439       96443  103219.0   50912  2109-12-30 01:40:00   1.6
#
#           VALUENUM VALUEUOM      FLAG
# ...

# %%
services = pd.read_csv("mimic-iii-clinical-database-1.4/SERVICES.csv.gz")
services
# Out:
#        ROW_ID  SUBJECT_ID  HADM_ID         TRANSFERTIME PREV_SERVICE  \
# 0         758         471   135879  2122-07-22 14:07:27        TSURG
# 1         759         471   135879  2122-07-26 18:31:49          MED
# 2         760         472   173064  2172-09-28 19:22:15          NaN
# 3         761         473   129194  2201-01-09 20:16:45          NaN
# 4         762         474   194246  2181-03-23 08:24:41          NaN
# ...       ...         ...      ...                  ...          ...
# 73338   72914       98932   174244  2176-08-13 20:28:00          NaN
# 73339   72915       98939   115549  2166-11-15 01:21:49          NaN
# 73340   72916       98941   141129  2118-02-08 01:52:28          NaN
# 73341   72917       98943   193747  2164-11-14 20:04:12          NaN
# 73342   72918       98944   112849  2130-10-23 14:39:52          NaN
#
#       CURR_SERVICE
# 0              MED
# 1            TSURG
# 2             CMED
# 3               NB
# 4               NB
# ...

# %%
microbiology_events = pd.read_csv("mimic-iii-clinical-database-1.4/MICROBIOLOGYEVENTS.csv.gz")
microbiology_events
# Out:
#         ROW_ID  SUBJECT_ID  HADM_ID            CHARTDATE            CHARTTIME  \
# 0          744          96   170324  2156-04-13 00:00:00  2156-04-13 14:18:00
# 1          745          96   170324  2156-04-20 00:00:00  2156-04-20 13:10:00
# 2          746          96   170324  2156-04-20 00:00:00  2156-04-20 16:00:00
# 3          747          96   170324  2156-04-20 00:00:00                  NaN
# 4          748          96   170324  2156-04-20 00:00:00                  NaN
# ...        ...         ...      ...                  ...                  ...
# 631721  630931       99783   126090  2125-11-05 00:00:00  2125-11-05 13:15:00
# 631722  630932       99783   126090  2125-11-06 00:00:00  2125-11-06 10:24:00
# 631723  630933       99783   126090  2125-11-06 00:00:00  2125-11-06 10:24:00
# 631724  630934       99783   126090  2125-11-07 00:00:00  2125-11-07 12:40:00
# 631725  630935       99783   126090  2125-11-07 00:00:00  2125-11-07 14:28:00
#
# ...

# %%
hosp_admission = pd.read_csv("mimic-iv-2.2/hosp/admissions.csv.gz")
hosp_admission
# Out:
#         subject_id   hadm_id            admittime            dischtime  \
# 0         10000032  22595853  2180-05-06 22:23:00  2180-05-07 17:15:00
# 1         10000032  22841357  2180-06-26 18:27:00  2180-06-27 18:49:00
# 2         10000032  25742920  2180-08-05 23:44:00  2180-08-07 17:50:00
# 3         10000032  29079034  2180-07-23 12:35:00  2180-07-25 17:55:00
# 4         10000068  25022803  2160-03-03 23:16:00  2160-03-04 06:26:00
# ...            ...       ...                  ...                  ...
# 431226    19999828  25744818  2149-01-08 16:44:00  2149-01-18 17:00:00
# 431227    19999828  29734428  2147-07-18 16:23:00  2147-08-04 18:10:00
# 431228    19999840  21033226  2164-09-10 13:47:00  2164-09-17 13:42:00
# 431229    19999840  26071774  2164-07-25 00:27:00  2164-07-28 12:15:00
# 431230    19999987  23865745  2145-11-02 21:38:00  2145-11-11 12:57:00
#
#                   deathtime  admission_type admit_provider_id  \
# ...

# %%
patient_hosp = pd.read_csv("mimic-iii-clinical-database-1.4/patients.csv.gz")
patient_hosp
# Out:
#        ROW_ID  SUBJECT_ID GENDER                  DOB                  DOD  \
# 0         234         249      F  2075-03-13 00:00:00                  NaN
# 1         235         250      F  2164-12-27 00:00:00  2188-11-22 00:00:00
# 2         236         251      M  2090-03-15 00:00:00                  NaN
# 3         237         252      M  2078-03-06 00:00:00                  NaN
# 4         238         253      F  2089-11-26 00:00:00                  NaN
# ...       ...         ...    ...                  ...                  ...
# 46515   31840       44089      M  2026-05-25 00:00:00                  NaN
# 46516   31841       44115      F  2124-07-27 00:00:00                  NaN
# 46517   31842       44123      F  2049-11-26 00:00:00  2135-01-12 00:00:00
# 46518   31843       44126      F  2076-07-25 00:00:00                  NaN
# 46519   31844       44128      M  2098-07-25 00:00:00                  NaN
#
#                   DOD_HOSP DOD_SSN  EXPIRE_FLAG
# ...

# %%
INPUTEVENTS_MV = pd.read_csv("mimic-iii-clinical-database-1.4/INPUTEVENTS_MV.csv.gz")
INPUTEVENTS_MV
# Out:
#           ROW_ID  SUBJECT_ID  HADM_ID  ICUSTAY_ID            STARTTIME  \
# 0            241       27063   139787    223259.0  2133-02-05 06:29:00
# 1            242       27063   139787    223259.0  2133-02-05 05:34:00
# 2            243       27063   139787    223259.0  2133-02-05 05:34:00
# 3            244       27063   139787    223259.0  2133-02-03 12:00:00
# 4            245       27063   139787    223259.0  2133-02-03 12:00:00
# ...          ...         ...      ...         ...                  ...
# 3618986  3568968       90959   136680    240741.0  2147-08-28 12:00:00
# 3618987  3568969       90959   136680    240741.0  2147-08-29 12:16:00
# 3618988  3568970       90959   136680    240741.0  2147-08-29 12:16:00
# 3618989  3568971       90959   136680    240741.0  2147-08-29 02:30:00
# 3618990  3568972       90959   136680    240741.0  2147-08-28 06:00:00
#
#                      ENDTIME  ITEMID      AMOUNT AMOUNTUOM        RATE  ...  \
# ...

# %%
INPUTEVENTS_MV.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 INPUTEVENTS_MV.columns
#
# NameError: name 'INPUTEVENTS_MV' is not defined

# %%
notevents
# Out:
#           ROW_ID  SUBJECT_ID  HADM_ID  ICUSTAY_ID            STARTTIME  \
# 0            241       27063   139787    223259.0  2133-02-05 06:29:00
# 1            242       27063   139787    223259.0  2133-02-05 05:34:00
# 2            243       27063   139787    223259.0  2133-02-05 05:34:00
# 3            244       27063   139787    223259.0  2133-02-03 12:00:00
# 4            245       27063   139787    223259.0  2133-02-03 12:00:00
# ...          ...         ...      ...         ...                  ...
# 3618986  3568968       90959   136680    240741.0  2147-08-28 12:00:00
# 3618987  3568969       90959   136680    240741.0  2147-08-29 12:16:00
# 3618988  3568970       90959   136680    240741.0  2147-08-29 12:16:00
# 3618989  3568971       90959   136680    240741.0  2147-08-29 02:30:00
# 3618990  3568972       90959   136680    240741.0  2147-08-28 06:00:00
#
#                      ENDTIME  ITEMID      AMOUNT AMOUNTUOM        RATE  ...  \
# ...

# %%
notevents.dtypes
# Out:
# ROW_ID                             int64
# SUBJECT_ID                         int64
# HADM_ID                            int64
# ICUSTAY_ID                       float64
# STARTTIME                         object
# ENDTIME                           object
# ITEMID                             int64
# AMOUNT                           float64
# AMOUNTUOM                         object
# RATE                             float64
# RATEUOM                           object
# STORETIME                         object
# CGID                               int64
# ORDERID                            int64
# LINKORDERID                        int64
# ORDERCATEGORYNAME                 object
# SECONDARYORDERCATEGORYNAME        object
# ORDERCOMPONENTTYPEDESCRIPTION     object
# ORDERCATEGORYDESCRIPTION          object
# PATIENTWEIGHT                    float64
# TOTALAMOUNT                      float64
# TOTALAMOUNTUOM                    object
# ISOPENBAG                          int64
# ...

# %%
NOTEEVENTS = pd.read_csv("mimic-iii-clinical-database-1.4/NOTEEVENTS.csv.gz")
# Out:
# /var/folders/kw/fxbbvv5x7lvct1l7rdc18tkw0000gn/T/ipykernel_62638/1499604582.py:1: DtypeWarning: Columns (4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   NOTEEVENTS = pd.read_csv("mimic-iii-clinical-database-1.4/NOTEEVENTS.csv.gz")

# %%
NOTEEVENTS
# Out:
#           ROW_ID  SUBJECT_ID   HADM_ID   CHARTDATE            CHARTTIME  \
# 0            174       22532  167853.0  2151-08-04                  NaN
# 1            175       13702  107527.0  2118-06-14                  NaN
# 2            176       13702  167118.0  2119-05-25                  NaN
# 3            177       13702  196489.0  2124-08-18                  NaN
# 4            178       26880  135453.0  2162-03-25                  NaN
# ...          ...         ...       ...         ...                  ...
# 2083175  2070657       31097  115637.0  2132-01-21  2132-01-21 03:27:00
# 2083176  2070658       31097  115637.0  2132-01-21  2132-01-21 09:50:00
# 2083177  2070659       31097  115637.0  2132-01-21  2132-01-21 16:42:00
# 2083178  2070660       31097  115637.0  2132-01-21  2132-01-21 18:05:00
# 2083179  2070661       31097  115637.0  2132-01-21  2132-01-21 18:05:00
#
#                    STORETIME           CATEGORY DESCRIPTION     CGID  ISERROR  \
# ...

# %%
NOTEEVENTS.dtypes
# Out:
# ROW_ID           int64
# SUBJECT_ID       int64
# HADM_ID        float64
# CHARTDATE       object
# CHARTTIME       object
# STORETIME       object
# CATEGORY        object
# DESCRIPTION     object
# CGID           float64
# ISERROR        float64
# TEXT            object
# dtype: object

# %%
INPUTEVENTS_CV = pd.read_csv("mimic-iii-clinical-database-1.4/INPUTEVENTS_CV.csv.gz")
INPUTEVENTS_CV
# Out:
# /var/folders/kw/fxbbvv5x7lvct1l7rdc18tkw0000gn/T/ipykernel_62638/3619590080.py:1: DtypeWarning: Columns (7,9,17,20,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   INPUTEVENTS_CV = pd.read_csv("mimic-iii-clinical-database-1.4/INPUTEVENTS_CV.csv.gz")
#             ROW_ID  SUBJECT_ID   HADM_ID  ICUSTAY_ID            CHARTTIME  \
# 0              592       24457  184834.0    205776.0  2193-09-11 09:00:00
# 1              593       24457  184834.0    205776.0  2193-09-11 12:00:00
# 2              594       24457  184834.0    205776.0  2193-09-11 16:00:00
# 3              595       24457  184834.0    205776.0  2193-09-11 19:00:00
# 4              596       24457  184834.0    205776.0  2193-09-11 21:00:00
# ...            ...         ...       ...         ...                  ...
# 17527930  17422687       27946  169481.0    212466.0  2154-07-16 22:00:00
# 17527931  17422688       27946  169481.0    212466.0  2154-07-16 23:00:00
# ...

# %%
INPUTEVENTS_CV.dtypes
# Out:
# ROW_ID                 int64
# SUBJECT_ID             int64
# HADM_ID              float64
# ICUSTAY_ID           float64
# CHARTTIME             object
# ITEMID                 int64
# AMOUNT               float64
# AMOUNTUOM             object
# RATE                 float64
# RATEUOM               object
# STORETIME             object
# CGID                 float64
# ORDERID                int64
# LINKORDERID            int64
# STOPPED               object
# NEWBOTTLE            float64
# ORIGINALAMOUNT       float64
# ORIGINALAMOUNTUOM     object
# ORIGINALROUTE         object
# ORIGINALRATE         float64
# ORIGINALRATEUOM       object
# ORIGINALSITE          object
# dtype: object

# %%
LABEVENTS = pd.read_csv("mimic-iii-clinical-database-1.4/LABEVENTS.csv.gz")
LABEVENTS
# Out:
#             ROW_ID  SUBJECT_ID   HADM_ID  ITEMID            CHARTTIME VALUE  \
# 0              281           3       NaN   50820  2101-10-12 16:07:00  7.39
# 1              282           3       NaN   50800  2101-10-12 18:17:00   ART
# 2              283           3       NaN   50802  2101-10-12 18:17:00    -1
# 3              284           3       NaN   50804  2101-10-12 18:17:00    22
# 4              285           3       NaN   50808  2101-10-12 18:17:00  0.93
# ...            ...         ...       ...     ...                  ...   ...
# 27854050  27428435       96443  103219.0   50882  2109-12-30 01:40:00    26
# 27854051  27428436       96443  103219.0   50885  2109-12-30 01:40:00   2.1
# 27854052  27428437       96443  103219.0   50902  2109-12-30 01:40:00    97
# 27854053  27428438       96443  103219.0   50911  2109-12-30 01:40:00     2
# 27854054  27428439       96443  103219.0   50912  2109-12-30 01:40:00   1.6
#
#           VALUENUM VALUEUOM      FLAG
# ...

# %%
LABEVENTS.dtypes
# Out:
# ROW_ID          int64
# SUBJECT_ID      int64
# HADM_ID       float64
# ITEMID          int64
# CHARTTIME      object
# VALUE          object
# VALUENUM      float64
# VALUEUOM       object
# FLAG           object
# dtype: object

# %%
hcp = pd.read_csv("mimic-iv-2.2/hosp/hcpcsevents.csv.gz")
hcp
# Out:
#         subject_id   hadm_id   chartdate hcpcs_cd  seq_num  \
# 0         10000068  25022803  2160-03-04    99218        1
# 1         10000084  29888819  2160-12-28    G0378        1
# 2         10000108  27250926  2163-09-27    99219        1
# 3         10000117  22927623  2181-11-15    43239        1
# 4         10000117  22927623  2181-11-15    G0378        2
# ...            ...       ...         ...      ...      ...
# 150766    19999379  26008899  2174-11-04    G0378        1
# 150767    19999466  21397174  2116-08-30    G0378        1
# 150768    19999733  27674281  2152-07-09    99219        1
# 150769    19999784  24935234  2119-07-09    99219        1
# 150770    19999784  24935234  2119-07-10    62270        2
#
#                     short_description
# 0       Hospital observation services
# 1         Hospital observation per hr
# 2       Hospital observation services
# 3                    Digestive system
# 4         Hospital observation per hr
# ...

# %%
p = pd.read_csv("mimic-iv-2.2/hosp/patients.csv.gz")
p
# Out:
#         subject_id gender  anchor_age  anchor_year anchor_year_group  \
# 0         10000032      F          52         2180       2014 - 2016
# 1         10000048      F          23         2126       2008 - 2010
# 2         10000068      F          19         2160       2008 - 2010
# 3         10000084      M          72         2160       2017 - 2019
# 4         10000102      F          27         2136       2008 - 2010
# ...            ...    ...         ...          ...               ...
# 299707    19999828      F          46         2147       2017 - 2019
# 299708    19999829      F          28         2186       2008 - 2010
# 299709    19999840      M          58         2164       2008 - 2010
# 299710    19999914      F          49         2158       2017 - 2019
# 299711    19999987      F          57         2145       2011 - 2013
#
#                dod
# 0       2180-09-09
# 1              NaN
# 2              NaN
# 3       2161-02-13
# 4              NaN
# ...
